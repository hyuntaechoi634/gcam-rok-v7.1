# %% [markdown]
# # Source
#
# ## Data Sources
# - [CLIMATE TRANSPARENCY REPORT: COMPARING G20 CLIMATE ACTION](https://www.climate-transparency.org/wp-content/uploads/2022/10/CT2022-South-Korea-Web.pdf)
# - [South Korea’s 2030 Methane Emissions Reduction Roadmap lacks 2050 vision & needs a sector -specific approach](https://forourclimate.org/newsroom/997)
#
# ## Implemented Input Files
# - `/input/policy/korea-2035/others/methane_tax.xml`
# - `/input/policy/korea-2035/others/methane_linked_ghg_policy.xml`

# %% [markdown]
# # Global Methane Pledge

# %% [markdown]
# South Korea has endorsed the *Global Methane Pledge* and formally ratified it.
# However, policy instruments to implement the pledge remain insufficient.
#
# In the *Current Policy* scenario, we assume that no measures are introduced to fulfill the GMP.
# In the *Enhanced Ambition* scenario, we assume the introduction of a carbon tax—converted using GWP values from AR5—at a level consistent with the projected EU ETS carbon prices, calculated following the methodology in `../industry/carbon_prices.ipynb`.

# %%
emiss_2020 = 35.6
emiss_2030 = emiss_2020 * 0.7
emiss_2035 = emiss_2020 * 0.55
emiss_2030, emiss_2035
# Out:
# (24.919999999999998, 19.580000000000002)
