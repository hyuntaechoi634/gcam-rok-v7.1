# %% [markdown]
# # Implementation of Waste Management Policies

# %% [markdown]
# Below are detailed implementation of waste management policies presented in `direct_landfill_ban.ipynb` and `UN_plastic_treaty.ipynb`.

# %% [markdown]
# * 2018: 17.1 MtCO2-eq

# %% [markdown]
# ## Current Policies

# %% [markdown]
# * 1.73 MtCO2-eq by 2030
# * 2.23 MtCO2-eq by 2035

# %%
1- 1.73/17.1
# Out:
# 0.8988304093567252

# %%
1 - 2.23/17.1
# Out:
# 0.8695906432748538

# %% [markdown]
# ## Enhanced Ambition

# %%
0.777 + 2.44
# Out:
# 3.217

# %%
1.554+ 3.17
# Out:
# 4.724

# %% [markdown]
# * 3.217 by 2030
# * 4.724 by 2035

# %%
1- 3.217/17.1
# Out:
# 0.8118713450292397

# %%
1 - 4.724/17.1
# Out:
# 0.7237426900584796

# %% [markdown]
# # Implementation

# %% [markdown]
# `../../input/policy/waste_management_cp.xml`
#
# ```xml
#
#
# <?xml version="1.0" encoding="UTF-8"?>
# <scenario>
#     <world>
#         <region name="South Korea">
#             <supplysector name="urban processes">
#                 <subsector name="waste_incineration">
#                     <stub-technology year="2030" name="waste_incineration">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>0.655196</emiss-coef>   <!-- 0.806892 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>0.0402810</emiss-coef>  <!-- 0.0496071 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>0.583383</emiss-coef>   <!-- 0.806892 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>0.035866</emiss-coef>   <!-- 0.0496071 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#                 <subsector name="landfills">
#                     <stub-technology name="landfills">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>22.100772</emiss-coef>  <!-- 27.2177 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>19.678397</emiss-coef>  <!-- 27.2177 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#                 <subsector name="wastewater">
#                     <stub-technology year="2030" name="wastewater">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>499.45308</emiss-coef>  <!-- 615.09 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>3.338400</emiss-coef>   <!-- 4.11133 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>444.71007</emiss-coef>   <!-- 615.09 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>2.972491</emiss-coef>   <!-- 4.11133 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#             </supplysector>
#         </region>
#     </world>
# </scenario>
#
# ```

# %% [markdown]
# `../../input/policy/waste_management_ep.xml`
#
# ```xml
#
# <?xml version="1.0" encoding="UTF-8"?>
# <scenario>
#     <world>
#         <region name="South Korea">
#             <supplysector name="urban processes">
#                 <subsector name="waste_incineration">
#                     <stub-technology year="2030" name="waste_incineration">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>0.655196</emiss-coef>   <!-- 0.806892 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>0.0402810</emiss-coef>  <!-- 0.0496071 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>0.583383</emiss-coef>   <!-- 0.806892 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>0.035866</emiss-coef>   <!-- 0.0496071 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#                 <subsector name="landfills">
#                     <stub-technology name="landfills">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>22.100772</emiss-coef>  <!-- 27.2177 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>19.678397</emiss-coef>  <!-- 27.2177 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#                 <subsector name="wastewater">
#                     <stub-technology year="2030" name="wastewater">
#                         <period year="2030">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>499.45308</emiss-coef>  <!-- 615.09 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>3.338400</emiss-coef>   <!-- 4.11133 × 0.812 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                         <period year="2035">
#                             <Non-CO2 name="CH4">
#                                 <emiss-coef>444.71007</emiss-coef>   <!-- 615.09 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                             <Non-CO2 name="N2O">
#                                 <emiss-coef>2.972491</emiss-coef>   <!-- 4.11133 × 0.723 -->
#                                 <output-driver/>
#                             </Non-CO2>
#                         </period>
#                     </stub-technology>
#                 </subsector>
#             </supplysector>
#         </region>
#     </world>
# </scenario>
#
#
# ```
