# %% [markdown]
# # Source
#
# ## Data Sources
# - Ministry of Trade, Industry and Energy. (2021, October 8). Government to establish 1 million tons of clean hydrogen production domestically by 2030 and foster 30 global hydrogen companies [Policy News]. Korea Policy Briefing. Retrieved from https://www.korea.kr/news/policyNewsView.do?newsId=148894079
#
# ## Implemented Input Files
# - `/input/policy/korea-2035/others/clean_hydrogen_credit_cp.xml`
# - `/input/policy/korea-2035/others/clean_hydrogen_credit_ep.xml`

# %% [markdown]
# # Clean Hydrogen Credit

# %% [markdown]
# By implementing the clean hydrogen credit, the share of clean hydrogen is projected to reach **50% by 2030** and **100% by 2050**.
# We linearly interpolated the clean hydrogen shares for the years between 2030 and 2050.
#
# For this policy, *clean hydrogen* is defined broadly as including all hydrogen types except grey hydrogen.
# In the *Enhanced Ambition* scenario, blue hydrogen is also excluded, and the 2030 target share is increased to **75%**.
#
# This policy is implemented in GCAM using the [Renewable Energy Standard (RES)](https://jgcri.github.io/gcam-doc/policies_examples.html#res) policy type.

# %% [markdown]
# 1st Hydrogen Economy Implementation Plan:
#
# Clean Hydrogen Share -
#
# * 2030: 51.55%
# * 2050: 100%

# %%
0.5155 + (1-0.5155) * (5 / 20)
# Out:
# 0.636625

# %% [markdown]
# * 2035: 63.66%
