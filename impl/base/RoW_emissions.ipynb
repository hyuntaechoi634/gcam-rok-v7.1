# %%
emiss_2020_co2_world_mtco2 = 36209.90
emiss_2020_co2_kor_mtco2 = 617.34
emiss_2020_co2_eu27_mtco2 = 3395.60

emiss_2024_co2_world_mtco2 = 39632.70
emiss_2024_co2_kor_mtco2 = 588.01
emiss_2024_co2_eu27_mtco2 = 3164.66 

emiss_2020_co2_row_mtco2 = emiss_2020_co2_world_mtco2 - emiss_2020_co2_kor_mtco2 - emiss_2020_co2_eu27_mtco2
emiss_2024_co2_row_mtco2 = emiss_2024_co2_world_mtco2 - emiss_2024_co2_kor_mtco2 - emiss_2024_co2_eu27_mtco2
emiss_2020_co2_row_mtco2, emiss_2024_co2_row_mtco2
# Out:
# (32196.960000000006, 35880.03)

# %%
emiss_2020_co2_row_mtc = emiss_2020_co2_row_mtco2 * (12 / 44)
emiss_2024_co2_row_mtc = emiss_2024_co2_row_mtco2 * (12 / 44)
emiss_2020_co2_row_mtc, emiss_2024_co2_row_mtc
# Out:
# (8780.989090909092, 9785.462727272727)

# %%
for year in range(2025, 2061, 5):
    emiss_mtc = emiss_2024_co2_row_mtc - ((year - 2024) / (2060-2024)) * emiss_2024_co2_row_mtc
    print(year, emiss_mtc)
# Out:
# 2025 9513.644318181818
# 2030 8154.552272727273
# 2035 6795.460227272726
# 2040 5436.368181818181
# 2045 4077.2761363636355
# 2050 2718.1840909090906
# 2055 1359.0920454545449
# 2060 0.0

# %%
emiss_1990_co2_eu27_mtco2 = 4864.28
emiss_1990_co2_eu27_mtc = emiss_1990_co2_eu27_mtco2 * (12 / 44)
emiss_1990_co2_eu27_mtc
# Out:
# 1326.621818181818

# %%
emiss_2030_co2_eu27_mtc = emiss_1990_co2_eu27_mtc * 0.45
emiss_2030_co2_eu27_mtc
# Out:
# 596.9798181818181

# %%
emiss_2040_co2_eu27_mtc = emiss_1990_co2_eu27_mtc * 0.1
emiss_2040_co2_eu27_mtc
# Out:
# 132.6621818181818

# %%
emiss_2035_co2_eu27_mtc = emiss_2030_co2_eu27_mtc + emiss_2040_co2_eu27_mtc
emiss_2035_co2_eu27_mtc /= 2
emiss_2035_co2_eu27_mtc
# Out:
# 364.82099999999997

# %%
emiss_2024_co2_eu27_mtc = emiss_2024_co2_eu27_mtco2 * (12 / 44)
emiss_2024_co2_eu27_mtc
# Out:
# 863.0890909090908

# %%
emiss_2025_co2_eu27_mtc = emiss_2024_co2_eu27_mtc + (emiss_2030_co2_eu27_mtc - emiss_2024_co2_eu27_mtc) * (1/6)
emiss_2025_co2_eu27_mtc
# Out:
# 818.7375454545454
